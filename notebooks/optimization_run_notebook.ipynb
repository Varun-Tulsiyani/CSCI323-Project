# %% [markdown]
# # Wave Energy Farm Optimization (Genetic Algorithm)

# %%
from scripts.optimization_ga import GeneticOptimizer
import matplotlib.pyplot as plt

# %%
optimizer = GeneticOptimizer(trained_model, nn_pipeline)

best_layout, history = optimizer.run()

print("Best layout:", best_layout)

# %%
plt.plot(history)
plt.xlabel("Generation")
plt.ylabel("Best Power")
plt.title("GA Convergence")
plt.show()

# %%
coords = best_layout.reshape(16,2)

plt.scatter(coords[:,0],coords[:,1])
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.title("Optimized Converter Layout")
plt.show()
